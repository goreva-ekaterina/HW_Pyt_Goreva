# %% [markdown]
# <center> <img src = https://raw.githubusercontent.com/AndreyRysistov/DatasetsForPandas/main/hh%20label.jpg alt="drawing" style="width:400px;">

# %% [markdown]
# # <center> Проект: Анализ резюме из HeadHunter

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %% [markdown]
# # Исследование структуры данных

# %% [markdown]
# 1. Прочитайте данные с помощью библиотеки Pandas. Совет: перед чтением обратите внимание на разделитель внутри файла.

# %%
#ваш код здесь
data = pd.read_csv('./dst-3.0_16_1_hh_database.csv', sep=';') 
data.head()
# Out:
#                                    Пол, возраст           ЗП  \
# 0    Мужчина ,  39 лет , родился 27 ноября 1979   29000 руб.
# 1     Мужчина ,  60 лет , родился 20 марта 1959   40000 руб.
# 2  Женщина ,  36 лет , родилась 12 августа 1982   20000 руб.
# 3      Мужчина ,  38 лет , родился 25 июня 1980  100000 руб.
# 4     Женщина ,  26 лет , родилась 3 марта 1993  140000 руб.
#
#                            Ищет работу на должность:  \
# 0                            Системный администратор
# 1                               Технический писатель
# 2                                           Оператор
# 3  Веб-разработчик (HTML / CSS / JS / PHP / базы ...
# 4                  Региональный менеджер по продажам
#
#                         Город, переезд, командировки  \
# 0  Советск (Калининградская область) , не готов к...
# 1  Королев , не готов к переезду , готов к редким...
# 2  Тверь , не готова к переезду , не готова к ком...
# 3  Саратов , не готов к переезду , готов к редким...
# ...

# %% [markdown]
# 2. Выведите несколько первых (последних) строк таблицы, чтобы убедиться в том, что ваши данные не повреждены. Ознакомьтесь с признаками и их структурой.

# %%
# первые строки мы вывели на предыдущем шаге
# выведем три последние
data.tail(3)
# Out:
#                                        Пол, возраст           ЗП  \
# 44741  Женщина ,  48 лет , родилась 26 декабря 1970   40000 руб.
# 44742   Мужчина ,  24 года , родился 6 октября 1994   20000 руб.
# 44743    Мужчина ,  38 лет , родился 25 апреля 1980  120000 руб.
#
#         Ищет работу на должность:  \
# 44741  Аналитик данных, Математик
# 44742            Контент-менеджер
# 44743        Руководитель проекта
#
#                             Город, переезд, командировки  \
# 44741  Челябинск , готова к переезду , готова к редки...
# 44742  Тамбов , не готов к переезду , не готов к кома...
# 44743  Москва , не готов к переезду , не готов к кома...
#
#                                    Занятость                         График  \
# 44741                       полная занятость  полный день, удаленная работа
# 44742  частичная занятость, полная занятость               удаленная работа
# 44743                       полная занятость                    полный день
#
# ...

# %% [markdown]
# 3. Выведите основную информацию о числе непустых значений в столбцах и их типах в таблице.

# %% [markdown]
# 4. Обратите внимание на информацию о числе непустых значений.

# %%
#ваш код здесь
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44744 entries, 0 to 44743
# Data columns (total 12 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Пол, возраст                     44744 non-null  object
#  1   ЗП                               44744 non-null  object
#  2   Ищет работу на должность:        44744 non-null  object
#  3   Город, переезд, командировки     44744 non-null  object
#  4   Занятость                        44744 non-null  object
#  5   График                           44744 non-null  object
#  6   Опыт работы                      44576 non-null  object
#  7   Последнее/нынешнее место работы  44743 non-null  object
#  8   Последняя/нынешняя должность     44742 non-null  object
#  9   Образование и ВУЗ                44744 non-null  object
#  10  Обновление резюме                44744 non-null  object
#  11  Авто                             44744 non-null  object
# ...

# %% [markdown]
# 5. Выведите основную статистическую информацию о столбцах.

# %%
#ваш код здесь
data.describe(include=['object'])
# Out:
#                                          Пол, возраст          ЗП  \
# count                                           44744       44744
# unique                                          16003         690
# top     Мужчина ,  32 года , родился 17 сентября 1986  50000 руб.
# freq                                               18        4064
#
#        Ищет работу на должность:  \
# count                      44744
# unique                     14929
# top      Системный администратор
# freq                        3099
#
#                              Город, переезд, командировки         Занятость  \
# count                                               44744             44744
# unique                                              10063                38
# top     Москва , не готов к переезду , не готов к кома...  полная занятость
# freq                                                 1261             30026
#
#              График                                        Опыт работы  \
# ...

# %% [markdown]
# # Преобразование данных

# %% [markdown]
# 1. Начнем с простого - с признака **"Образование и ВУЗ"**. Его текущий формат это: **<Уровень образования год выпуска ВУЗ специальность...>**. Например:
# * Высшее образование 2016 Московский авиационный институт (национальный исследовательский университет)...
# * Неоконченное высшее образование 2000  Балтийская государственная академия рыбопромыслового флота…
# Нас будет интересовать только уровень образования.
#
# Создайте с помощью функции-преобразования новый признак **"Образование"**, который должен иметь 4 категории: "высшее", "неоконченное высшее", "среднее специальное" и "среднее".
#
# Выполните преобразование, ответьте на контрольные вопросы и удалите признак "Образование и ВУЗ".
#
# Совет: обратите внимание на структуру текста в столбце **"Образование и ВУЗ"**. Гарантируется, что текущий уровень образования соискателя всегда находится в первых 2ух слов и начинается с заглавной буквы. Воспользуйтесь этим.
#
# *Совет: проверяйте полученные категории, например, с помощью метода unique()*

# %%
#ваш код здесь
# создадим функцию edu_level, чтобы преобразовать образование в категории
def edu_level(education):
    education = education.lower()
    edu_cat = education.split(' ')
    if edu_cat[0] == 'высшее':
        return 'высшее'
    elif edu_cat[0] == 'неоконченное':
        return 'неоконченное высшее'
    elif edu_cat[1] == 'специальное':
        return 'среднее специальное'
    elif edu_cat[0] == 'среднее':
        return 'среднее'

# создадим таблицу и с образованием по категориям
data_copy1 = data.copy()
data_copy1['Образование'] = data_copy1['Образование и ВУЗ'].apply(edu_level)
# количество уникальных значений (их должно быть 4)
print(data_copy1['Образование'].nunique())
# количество пропусков в столбце
print(data_copy1['Образование'].isnull().sum())
# удаляем колонку "Образование и ВУЗ"
data_copy1 = data_copy1.drop(['Образование и ВУЗ'], axis=1)


# контрольное задание с платформы:
print(f"Количество соискателей со средним образованием:{data_copy1['Образование'].value_counts().loc['среднее']}")
# Out:
# 4
# 0
# Количество соискателей со средним образованием:559

# %% [markdown]
# 2. Теперь нас интересует столбец **"Пол, возраст"**. Сейчас он представлен в формате **<Пол , возраст , дата рождения >**. Например:
# * Мужчина , 39 лет , родился 27 ноября 1979
# * Женщина , 21 год , родилась 13 января 2000
# Как вы понимаете, нам необходимо выделить каждый параметр в отдельный столбец.
#
# Создайте два новых признака **"Пол"** и **"Возраст"**. При этом важно учесть:
# * Признак пола должен иметь 2 уникальных строковых значения: 'М' - мужчина, 'Ж' - женщина.
# * Признак возраста должен быть представлен целыми числами.
#
# Выполните преобразование, ответьте на контрольные вопросы и удалите признак **"Пол, возраст"** из таблицы.
#
# *Совет: обратите внимание на структуру текста в столбце, в части на то, как разделены параметры пола, возраста и даты рождения между собой - символом ' , '.
# Гарантируется, что структура одинакова для всех строк в таблице. Вы можете воспользоваться этим.*

# %%
#ваш код здесь
# создаем признаки "пол" и "возраст"
data_copy1['Пол'] = data_copy1['Пол, возраст'].apply(lambda x: x.split(',')[0][0])
data_copy1['Возраст'] = data_copy1['Пол, возраст'].apply(lambda x: int(x.split(',')[1][0:5]))
# количество уникальных значений в столбце "пол" (их должно быть 2)
print(data_copy1['Пол'].nunique())
# количество пропусков в столбце "Пол"
print(data_copy1['Пол'].isnull().sum())
# количество пропусков в столбце "Возраст"
print(data_copy1['Возраст'].isnull().sum())

# удаляем старый столбец с полом и возрастом
data_copy1 = data_copy1.drop(['Пол, возраст'], axis=1)

# проверочное задание на платформе
print(f"Процент соискателей-женщин: {round(data_copy1['Пол'].value_counts(normalize=True)[1]*100, 2)}%")
print(f"Средний возраст соискателей : {round(data_copy1['Возраст'].mean(), 1)} года")
# Out:
# 2
# 0
# 0
# Процент соискателей-женщин: 19.07%
# Средний возраст соискателей : 32.2 года

# %% [markdown]
# 3. Следующим этапом преобразуем признак **"Опыт работы"**. Его текущий формат - это: **<Опыт работы: n лет m месяцев, периоды работы в различных компаниях…>**.
#
# Из столбца нам необходимо выделить общий опыт работы соискателя в месяцах, новый признак назовем "Опыт работы (месяц)"
#
# Для начала обсудим условия решения задачи:
# * Во-первых, в данном признаке есть пропуски. Условимся, что если мы встречаем пропуск, оставляем его как есть (функция-преобразование возвращает NaN)
# * Во-вторых, в данном признаке есть скрытые пропуски. Для некоторых соискателей в столбце стоит значения "Не указано". Их тоже обозначим как NaN (функция-преобразование возвращает NaN)
# * В-третьих, нас не интересует информация, которая описывается после указания опыта работы (периоды работы в различных компаниях)
# * В-четвертых, у нас есть проблема: опыт работы может быть представлен только в годах или только месяцах. Например, можно встретить следующие варианты:
#     * Опыт работы 3 года 2 месяца…
#     * Опыт работы 4 года…
#     * Опыт работы 11 месяцев…
#     * Учитывайте эту особенность в вашем коде
#
# Учитывайте эту особенность в вашем коде
#
# В результате преобразования у вас должен получиться столбец, содержащий информацию о том, сколько месяцев проработал соискатель.
# Выполните преобразование, ответьте на контрольные вопросы и удалите столбец **"Опыт работы"** из таблицы.

# %%
#ваш код здесь
# функция для перевода опыта в месяцы
def exp_mon(exp):
    year_exp= ['лет', 'года', 'год']
    month_exp = ['месяц','месяца', 'месяцев']
    year = 0
    month = 0
    if exp == "Не указано" or exp is np.nan: 
        return np.nan
    else:
        exp = exp.split(' ')        
        for num in range(6):        
            if exp[num] in year_exp:
                year = int(exp[num-1])
            elif exp[num] in month_exp:
                month = int(exp[num-1])
            else:
                continue
    return year*12 + month

# создаем новый признак  
data_copy1['Опыт работы (месяц)'] = data_copy1['Опыт работы'].apply(exp_mon)

# удаляем старый признак
data_copy1 = data_copy1.drop(['Опыт работы'], axis=1)

# проверочное задание с платформы
print(f"Медианное значение опыта (в месяцах): {data_copy1['Опыт работы (месяц)'].median()} месяцев")
# Out:
# Медианное значение опыта (в месяцах): 100.0 месяцев

# %% [markdown]
# 4. Хорошо идем! Следующий на очереди признак "Город, переезд, командировки". Информация в нем представлена в следующем виде: **<Город , (метро) , готовность к переезду (города для переезда) , готовность к командировкам>**. В скобках указаны необязательные параметры строки. Например, можно встретить следующие варианты:
#
# * Москва , не готов к переезду , готов к командировкам
# * Москва , м. Беломорская , не готов к переезду, не готов к командировкам
# * Воронеж , готов к переезду (Сочи, Москва, Санкт-Петербург) , готов к командировкам
#
# Создадим отдельные признаки **"Город"**, **"Готовность к переезду"**, **"Готовность к командировкам"**. При этом важно учесть:
#
# * Признак **"Город"** должен содержать только 4 категории: "Москва", "Санкт-Петербург" и "город-миллионник" (их список ниже), остальные обозначьте как "другие".
#
#     Список городов-миллионников:
#
#    <code>million_cities = ['Новосибирск', 'Екатеринбург','Нижний Новгород','Казань', 'Челябинск','Омск', 'Самара', 'Ростов-на-Дону', 'Уфа', 'Красноярск', 'Пермь', 'Воронеж','Волгоград']
#     </code>
#     Инфорация о метро, рядом с которым проживает соискатель нас не интересует.
# * Признак **"Готовность к переезду"** должен иметь два возможных варианта: True или False. Обратите внимание, что возможны несколько вариантов описания готовности к переезду в признаке "Город, переезд, командировки". Например:
#     * … , готов к переезду , …
#     * … , не готова к переезду , …
#     * … , готова к переезду (Москва, Санкт-Петербург, Ростов-на-Дону)
#     * … , хочу переехать (США) , …
#
#     Нас интересует только сам факт возможности или желания переезда.
# * Признак **"Готовность к командировкам"** должен иметь два возможных варианта: True или False. Обратите внимание, что возможны несколько вариантов описания готовности к командировкам в признаке "Город, переезд, командировки". Например:
#     * … , готов к командировкам , …
#     * … , готова к редким командировкам , …
#     * … , не готов к командировкам , …
#
#     Нас интересует только сам факт готовности к командировке.
#
#     Еще один важный факт: при выгрузки данных у некоторых соискателей "потерялась" информация о готовности к командировкам. Давайте по умолчанию будем считать, что такие соискатели не готовы к командировкам.
#
# Выполните преобразования и удалите столбец **"Город, переезд, командировки"** из таблицы.
#
# *Совет: обратите внимание на то, что структура текста может меняться в зависимости от указания ближайшего метро. Учите это, если будете использовать порядок слов в своей программе.*

# %%
#ваш код здесь
# тут мы все-таки используем модуль re для работы с текстом
import re

# функция для определения города 
def city_name(city):
    million_cities = [
        'Новосибирск', 'Екатеринбург','Нижний Новгород',
        'Казань', 'Челябинск','Омск', 'Самара', 'Ростов-на-Дону',
        'Уфа', 'Красноярск', 'Пермь', 'Воронеж','Волгоград']
    city = city.split(' ')
    if city[0] == 'Москва':
        return 'Москва'
    elif city[0] == 'Санкт-Петербург':
        return 'Санкт-Петербург'
    elif city[0] in million_cities:
        return 'город-миллионник'
    else:
        return 'другие'
# создаем признак и проверяем результат
data_copy1['Город'] = data_copy1['Город, переезд, командировки'].apply(city_name)
display(data_copy1['Город'].value_counts())

# функция для оперделения готовности к переезду
def ready_to_relocation(reloc):
    reloc = reloc.split(',')
    for x in reloc:
        if re.findall(r'ерее', x) == ['ерее']:
            if ('готов' in x or 'хочу' in x) and ('не готов' not in x):
                return True
            else:
                return False
# проверяем
data_copy1['Готовность к переезду'] = data_copy1['Город, переезд, командировки'].apply(ready_to_relocation)
display(data_copy1['Готовность к переезду'].value_counts())
   
# определение готовности к командировкам         
def business_trip(bt):
    if 'командировка' in bt:
        if (re.findall(r'не готов к командировкам', bt) == ['не готов к командировкам']) \
        or (re.findall(r'не готова к командировкам', bt) == ['не готова к командировкам']):
            return False
        else:
            return True
    else:
        return False
    
# проверяем новый признак
data_copy1['Готовность к командировкам'] = data_copy1['Город, переезд, командировки'].apply(business_trip)
display(data_copy1['Готовность к командировкам'].value_counts())

# удаляем старый признак
data_copy1 = data_copy1.drop(['Город, переезд, командировки'], axis=1)

# проверочные задание на платформе
# Сколько процентов соискателей живут в Санкт-Петербурге? Ответ округлите до целого.
spb=round(data_copy1['Город'].value_counts(normalize=True)*100)['Санкт-Петербург']
print(spb)
      
# Сколько процентов соискателей готовы одновременно и к переездам, и к командировкам? Ответ округлите до целого.
ready_for_all = (data_copy1['Готовность к командировкам']) & (data_copy1['Готовность к переезду'])
all_trip = round(data_copy1[ready_for_all]['Готовность к командировкам'].count() / data_copy1.shape[0]*100)
print(all_trip)
# Out:
# Москва              16621
# другие              16452
# город-миллионник     6734
# Санкт-Петербург      4937
# Name: Город, dtype: int64
# False    28719
# True     16025
# Name: Готовность к переезду, dtype: int64
# True     31640
# False    13104
# Name: Готовность к командировкам, dtype: int64
# 11.0
# 32

# %% [markdown]
# 5. Рассмотрим поближе признаки **"Занятость"** и **"График"**. Сейчас признаки представляют собой набор категорий желаемой занятости (полная занятость, частичная занятость, проектная работа, волонтерство, стажировка) и желаемого графика работы (полный день, сменный график, гибкий график, удаленная работа, вахтовый метод).
# На сайте hh.ru соискатель может указывать различные комбинации данных категорий, например:
# * полная занятость, частичная занятость
# * частичная занятость, проектная работа, волонтерство
# * полный день, удаленная работа
# * вахтовый метод, гибкий график, удаленная работа, полная занятость
#
# Такой вариант признаков имеет множество различных комбинаций, а значит множество уникальных значений, что мешает анализу. Нужно это исправить!
#
# Давайте создадим признаки-мигалки для каждой категории: если категория присутствует в списке желаемых соискателем, то в столбце на месте строки рассматриваемого соискателя ставится True, иначе - False.
#
# Такой метод преобразования категориальных признаков называется One Hot Encoding и его схема представлена на рисунке ниже:
# <img src=https://raw.githubusercontent.com/AndreyRysistov/DatasetsForPandas/main/ohe.jpg>
# Выполните данное преобразование для признаков "Занятость" и "График", ответьте на контрольные вопросы, после чего удалите их из таблицы

# %%
#ваш код здесь
# формируем новые признаки
# варианты графика
data_copy1['полный день'] = data_copy1['График'].apply(lambda x: True if 'полный день' in x else False)
data_copy1['сменный график'] = data_copy1['График'].apply(lambda x: True if 'сменный график' in x else False)
data_copy1['гибкий график'] = data_copy1['График'].apply(lambda x: True if 'гибкий график' in x else False)
data_copy1['удаленная работа'] = data_copy1['График'].apply(lambda x: True if 'удаленная работа' in x else False)
data_copy1['вахтовый метод'] = data_copy1['График'].apply(lambda x: True if 'вахтовый метод' in x else False)
# варианты занятости
data_copy1['полная занятость'] = data_copy1['Занятость'].apply(lambda x: True if 'полная занятость' in x else False)
data_copy1['частичная занятость'] = data_copy1['Занятость'].apply(lambda x: True if 'частичная занятость' in x else False)
data_copy1['проектная работа'] = data_copy1['Занятость'].apply(lambda x: True if 'проектная работа' in x else False)
data_copy1['волонтерство'] = data_copy1['Занятость'].apply(lambda x: True if 'волонтерство' in x else False)
data_copy1['стажировка'] = data_copy1['Занятость'].apply(lambda x: True if 'стажировка' in x else False)

# удаляем старый признак
data_copy1 = data_copy1.drop(['Занятость', 'График'], axis=1)

# проверочное здание
# Сколько людей ищут проектную работу и волонтёрство 
work_and_vol = (data_copy1['проектная работа'] == True) & (data_copy1['волонтерство'] == True)
print(data_copy1[work_and_vol].shape[0])

# Сколько людей хотят работать вахтовым методом и с гибким графиком 
remote_and_flex = (data_copy1['вахтовый метод'] == True) & (data_copy1['гибкий график'] == True)
print(data_copy1[remote_and_flex].shape[0])
# Out:
# 436
# 2311

# %% [markdown]
# 6. (2 балла) Наконец, мы добрались до самого главного и самого важного - признака заработной платы **"ЗП"**.
# В чем наша беда? В том, что помимо желаемой заработной платы соискатель указывает валюту, в которой он бы хотел ее получать, например:
# * 30000 руб.
# * 50000 грн.
# * 550 USD
#
# Нам бы хотелось видеть заработную плату в единой валюте, например, в рублях. Возникает вопрос, а где взять курс валют по отношению к рублю?
#
# На самом деле язык Python имеет в арсенале огромное количество возможностей получения данной информации, от обращения к API Центробанка, до использования специальных библиотек, например pycbrf. Однако, это не тема нашего проекта.
#
# Поэтому мы пойдем в лоб: обратимся к специальным интернет-ресурсам для получения данных о курсе в виде текстовых файлов. Например, MDF.RU, данный ресурс позволяет удобно экспортировать данные о курсах различных валют и акций за указанные периоды в виде csv файлов. Мы уже сделали выгрузку курсов валют, которые встречаются в наших данных за период с 29.12.2017 по 05.12.2019. Скачать ее вы можете **на платформе**
#
# Создайте новый DataFrame из полученного файла. В полученной таблице нас будут интересовать столбцы:
# * "currency" - наименование валюты в ISO кодировке,
# * "date" - дата,
# * "proportion" - пропорция,
# * "close" - цена закрытия (последний зафиксированный курс валюты на указанный день).
#
#
# Перед вами таблица соответствия наименований иностранных валют в наших данных и их общепринятых сокращений, которые представлены в нашем файле с курсами валют. Пропорция - это число, за сколько единиц валюты указан курс в таблице с курсами. Например, для казахстанского тенге курс на 20.08.2019 составляет 17.197 руб. за 100 тенге, тогда итоговый курс равен - 17.197 / 100 = 0.17197 руб за 1 тенге.
# Воспользуйтесь этой информацией в ваших преобразованиях.
#
# <img src=https://raw.githubusercontent.com/AndreyRysistov/DatasetsForPandas/main/table.jpg>
#
#
# Осталось только понять, откуда брать дату, по которой определяется курс? А вот же она - в признаке **"Обновление резюме"**, в нем содержится дата и время, когда соискатель выложил текущий вариант своего резюме. Нас интересует только дата, по ней бы и будем сопоставлять курсы валют.
#
# Теперь у нас есть вся необходимая информация для того, чтобы создать признак "ЗП (руб)" - заработная плата в рублях.
#
# После ответа на контрольные вопросы удалите исходный столбец заработной платы "ЗП" и все промежуточные столбцы, если вы их создавали.

# %% [markdown]
# Итак, давайте обсудим возможный алгоритм преобразования:
# 1. Перевести признак "Обновление резюме" из таблицы с резюме в формат datetime и достать из него дату. В тот же формат привести признак "date" из таблицы с валютами.
# 2. Выделить из столбца "ЗП" сумму желаемой заработной платы и наименование валюты, в которой она исчисляется. Наименование валюты перевести в стандарт ISO согласно с таблицей выше.
# 3. Присоединить к таблице с резюме таблицу с курсами по столбцам с датой и названием валюты (подумайте, какой тип объединения надо выбрать, чтобы в таблице с резюме сохранились данные о заработной плате, изначально представленной в рублях). Значение close для рубля заполнить единицей 1 (курс рубля самого к себе)
# 4. Умножить сумму желаемой заработной платы на присоединенный курс валюты (close) и разделить на пропорцию (обратите внимание на пропуски после объединения в этих столбцах), результат занести в новый столбец "ЗП (руб)".

# %%
# дату из таблицу переводим в datetime 
data_copy1['Обновление резюме'] = pd.to_datetime(data_copy1['Обновление резюме'], dayfirst=True)
data_copy1['Обновление резюме'] = data_copy1['Обновление резюме'].dt.date
# таблица с курсами 
exchenge = pd.read_csv('ExchangeRates.csv')
# преобразуем формат даты
exchenge['date'] = pd.to_datetime(exchenge['date'], dayfirst=True)
# преобразуем зарплату в нужный вид через лямбда-функции
data_copy1['currency'] = data_copy1['ЗП'].apply(lambda x: x.split()[1])
data_copy1['sum'] = data_copy1['ЗП'].apply(lambda x: x.split()[0])
data_copy1['sum'] = data_copy1['sum'].astype('float')
# меняем обозначения 
currency={
    'руб.':'RUB',
    'грн.':'UAH',
    'USD':'USD',
    'EUR':'EUR',
    'бел.руб.':'BYN',
    'KGS':'KGS',
    'сум':'UZS',
    'AZN':'AZN',
    'KZT':'KZT'
    }
data_copy1['currency'] = data_copy1['currency'].apply(lambda x: currency[x])
# соединение таблицы  c датой и курсом
cur_and_data = data_copy1.copy()
cur_and_data['Обновление резюме'] = pd.to_datetime(cur_and_data['Обновление резюме'])
cur_and_data = cur_and_data.merge(exchenge, 
                                  left_on=['currency', 'Обновление резюме'], 
                                  right_on=['currency', 'date'],
                                  how='left')
cur_and_data['close'] = cur_and_data['close'].fillna(1)
cur_and_data['proportion'] = cur_and_data['proportion'].fillna(1)

# признак с ЗП в рублях
cur_and_data['ЗП (руб)'] = (cur_and_data['sum'] * cur_and_data['close']) / cur_and_data['proportion']

# удалим лишние столбцы 
cur_and_data = cur_and_data.drop(['ЗП','currency', 'sum', 'date', 'close', 'proportion'], axis=1)
# итого, таблица такая:
cur_and_data.head()
# Out:
#                            Ищет работу на должность:  \
# 0                            Системный администратор
# 1                               Технический писатель
# 2                                           Оператор
# 3  Веб-разработчик (HTML / CSS / JS / PHP / базы ...
# 4                  Региональный менеджер по продажам
#
#   Последнее/нынешнее место работы  \
# 0         МАОУ "СОШ № 1 г.Немана"
# 1    Временный трудовой коллектив
# 2                    ПАО Сбербанк
# 3                        OpenSoft
# 4                        Мармелад
#
#                        Последняя/нынешняя должность Обновление резюме  \
# 0                           Системный администратор        2019-04-16
# 1  Менеджер проекта, Аналитик, Технический писатель        2019-04-12
# 2                               Кассир-операционист        2019-04-16
# 3                               Инженер-программист        2019-04-08
# 4                              Менеджер по продажам        2019-04-22
#
# ...

# %%
# проверочное задание
#Чему равна желаемая медианная заработная плата соискателей в нашей таблице (в рублях)? Ответ приведите в тысячах рублей и округлите до целого. 
sellary = round(cur_and_data['ЗП (руб)'].median() / 1000)
print(sellary)
# Out:
# 59

# %% [markdown]
# # Исследование зависимостей в данных

# %% [markdown]
# 1. Постройте распределение признака **"Возраст"**. Опишите распределение, отвечая на следующие вопросы: чему равна мода распределения, каковы предельные значения признака, в каком примерном интервале находится возраст большинства соискателей? Есть ли аномалии для признака возраста, какие значения вы бы причислили к их числу?
# *Совет: постройте гистограмму и коробчатую диаграмму рядом.*

# %%
# картинка с гистограммой и боксплотом
fig, ax = plt.subplots(1, 2, figsize=(12, 6))
sns.histplot(cur_and_data['Возраст'], bins=100, color='skyblue', edgecolor='black', ax=ax[0])
mean_value = np.mean(cur_and_data['Возраст'])
ax[0].axvline(mean_value, color='r', linestyle='dashed', linewidth=2)
ax[0].set_title('Histogram with Mean Line')

sns.boxplot(cur_and_data['Возраст'], ax=ax[1], color='lightgreen')
ax[1].set_title('Boxplot')

plt.tight_layout()

plt.show()

# ищем моду растределения возраста
import statistics 
mod_of_age=statistics.mode(cur_and_data['Возраст']) 
print(mod_of_age)
# с помощью квантилей найдем самые частые значния
print(np.quantile(cur_and_data['Возраст'], 0.25))
print(np.quantile(cur_and_data['Возраст'], 0.75))
# Out:
# 30
# 27.0
# 36.0

# %% [markdown]
# Итак, модальное значение возраста развно 30. Распределение возраста отлино от нормального, но одномодальное. Возраст большей части соискателей находится в интервале от 27 до 36 лет. Есть аномальное значение возраста  - 100 лет. Это, наверное, единсвенное значение, которое стоит чистить. Остальные напоминают не выбросы, а просто пожилых кандидатов.

# %% [markdown]
# 2. Постройте распределение признака **"Опыт работы (месяц)"**. Опишите данное распределение, отвечая на следующие вопросы: чему равна мода распределения, каковы предельные значения признака, в каком примерном интервале находится опыт работы большинства соискателей? Есть ли аномалии для признака опыта работы, какие значения вы бы причислили к их числу?
# *Совет: постройте гистограмму и коробчатую диаграмму рядом.*

# %%
# ваш код здесь
# картинка с гистограммой и боксплотом
fig, ax = plt.subplots(1, 2, figsize=(12, 6))
sns.histplot(cur_and_data['Опыт работы (месяц)'], bins=100, color='skyblue', edgecolor='black', ax=ax[0])
mean_value = np.mean(cur_and_data['Опыт работы (месяц)'])
ax[0].axvline(mean_value, color='r', linestyle='dashed', linewidth=2)
ax[0].set_title('Histogram with Mean Line')

sns.boxplot(cur_and_data['Опыт работы (месяц)'], ax=ax[1], color='lightgreen')
ax[1].set_title('Boxplot')

plt.tight_layout()

plt.show()

# ищем моду растределения возраста
import statistics 
mod_of_exp=statistics.mode(cur_and_data['Опыт работы (месяц)']) 
print(mod_of_exp)
# Out:
# 81.0

# %% [markdown]
# Распредление нормальное, одномодальное. Мода равна 81 месяцу. Большая часть наблюдений лежит в промежутке от 0 до 200 месяцев. У нас есть некоторое значение больше 600, т.е. более 50 лет работы, но они не противоречат здравому смыслу. 1200 месяцев - это точно аномальных выборос.

# %% [markdown]
# 3. Постройте распределение признака **"ЗП (руб)"**. Опишите данное распределение, отвечая на следующие вопросы: каковы предельные значения признака, в каком примерном интервале находится заработная плата большинства соискателей? Есть ли аномалии для признака возраста? Обратите внимание на гигантские размеры желаемой заработной платы.
# *Совет: постройте гистограмму и коробчатую диаграмму рядом.*

# %%
# чтобы адекватно отобразить этот признак будем использовать логарифмирование
hist = sns.histplot(
    data=cur_and_data, 
    x=np.log(cur_and_data['ЗП (руб)']),
    )
# Строим линию среднего значения для определения ассиметрии распределения
hist.axvline(np.log(cur_and_data['ЗП (руб)']).mean(), color='g', lw='4')

# Повышаем информативность
hist.set_title('Гистограмма желаемой зарпалаты Log')
hist.set_xlabel('Желаемая зарпалата') 
hist.set_ylabel('Количество наблюдений')
hist.grid()
plt.show()

# мода
print('Мода желаемой зарплаты:', cur_and_data['ЗП (руб)'].mode()[0])
# с помощью квантилей найдем самые частые значния
print(np.quantile(cur_and_data['ЗП (руб)'], 0.25))
print(np.quantile(cur_and_data['ЗП (руб)'], 0.75))
# Out:
# Мода желаемой зарплаты: 50000.0
# 37082.2
# 95000.0

# %% [markdown]
# Мода желаемой зарплаты равна 50 тысячас рублей. Распредение отлично от нормального. Интервал наиболее часто желаемой зп находится в пределах 37082 до 95000 руб.

# %% [markdown]
# 4. Постройте диаграмму, которая показывает зависимость **медианной** желаемой заработной платы (**"ЗП (руб)"**) от уровня образования (**"Образование"**). Используйте для диаграммы данные о резюме, где желаемая заработная плата меньше 1 млн рублей.
# *Сделайте выводы по представленной диаграмме: для каких уровней образования наблюдаются наибольшие и наименьшие уровни желаемой заработной платы? Как вы считаете, важен ли признак уровня образования при прогнозировании заработной платы?*

# %%
# ваш код здесь
# фильтруем (до 1 млн.руб) и группируем по признаку образования
mask = (cur_and_data['ЗП (руб)'] < 1000000)
df = cur_and_data[mask].groupby('Образование', as_index=False)['ЗП (руб)'].median()

fig = plt.figure(figsize=(8, 4))
bar = sns.barplot(
    df,
    x='ЗП (руб)',
    y='Образование',
    width=-0.75     
    )

# Повышаем информативность
bar.set_title('Медиана желаемой зарплаты от уровня образования')
bar.set_xlabel('Желаемая ЗП')
bar.set_ylabel('Группы по уровню образования')
bar.grid()

plt.show()

# %% [markdown]
# Видим, что медиана по группе с высшим образованием = 60 000, неоконченным - 50 000 , средним и средним спецаильным - 40 000. Да, уровень образования важен для прогнозирования ЗП.

# %% [markdown]
# 5. Постройте диаграмму, которая показывает распределение желаемой заработной платы (**"ЗП (руб)"**) в зависимости от города (**"Город"**). Используйте для диаграммы данные о резюме, где желая заработная плата меньше 1 млн рублей.
# *Сделайте выводы по полученной диаграмме: как соотносятся медианные уровни желаемой заработной платы и их размах в городах? Как вы считаете, важен ли признак города при прогнозировании заработной платы?*

# %%
# ваш код здесь
# группируем  данные по признаку "город" для случаев с ЗП меньше миллиона
mask = (cur_and_data['ЗП (руб)'] < 1000000)
df = cur_and_data[mask]
bar_data = cur_and_data[mask].groupby('Город', as_index=False) ['ЗП (руб)'].median()
fig, axes = plt.subplots(2, 1, figsize=(6, 12))
box = sns.boxplot(
    df,
    x='ЗП (руб)',
    y='Город',   
    orient='h',
    ax=axes[0]
    )
box.set_title('зависимость желаемой ЗП от города')
box.set_xlabel('Желаемая ЗП, руб.')
box.set_ylabel('Город проживания')
box.grid()
# столбчатая диаграмма 
bar = sns.barplot(
    bar_data,
    x='ЗП (руб)',
    y='Город',    
    ax=axes[1] 
    )

bar.set_title('ависимость желаемой ЗП от города')
bar.set_xlabel('Желаемая ЗП')
bar.set_ylabel('Город проживания')
bar.grid()

plt.show()

# %% [markdown]
# Город при прогнозировании ЗП , очевидно, важен. ЗП больше 80 тысяч рублей (по медиане) ожидаются от работодателей в Москве. В Манкт-Петербурге  медиана составляет 60 тысяч. В городах-милионниках и других значимой разницы нет (40 тысяч рублей - желаемый уровень ЗП).  Во всех четырех случаях у нас есть выбросы в большую сторону (мы не будем их чистить, т.к. цифры не противоречат здравому смыслу: такие зарплаты вполне возможны).

# %% [markdown]
# 6. Постройте **многоуровневую столбчатую диаграмму**, которая показывает зависимость медианной заработной платы (**"ЗП (руб)"**) от признаков **"Готовность к переезду"** и **"Готовность к командировкам"**. Проанализируйте график, сравнив уровень заработной платы в категориях.

# %%
# ваш код здесь
# фильтруем и группируем
mask = (cur_and_data['ЗП (руб)'] < 1000000)
df = cur_and_data[mask].groupby(['Готовность к переезду', 'Готовность к командировкам'], as_index=False) ['ЗП (руб)'].median()

# строим барплот

bar = sns.barplot(
    df,
    x='Готовность к командировкам',
    y='ЗП (руб)',
    hue='Готовность к переезду',
    )

bar.set_title('Зависимость желаемой ЗП от готовности к переездам и командировкам')
bar.set_xlabel('Готовность к командировкам')
bar.set_ylabel('Желаемая ЗП, руб.')
bar.grid()
bar.set(xticklabels=["Не готов", "Готов"])

plt.show()
# Out:
# C:\Users\Мщй котик-троцкист\AppData\Local\Temp\ipykernel_13132\3470214061.py:19: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   bar.set(xticklabels=["Не готов", "Готов"])

# %% [markdown]
# Да, готовность к переезду и командировкам играет роль. Самоя большая медиана зарплаты в категории готовых к командировкам и переезду. Чуть меньшая медианная ЗП у категории соискателей готовые только к командировкам, готовые только к перезду, не готовые к командировкам и переездам. Самая маленькая ожидаемая ЗП наблюдается у тех, кто не готов ни к тому, ни к другому.

# %% [markdown]
# 7. Постройте сводную таблицу, иллюстрирующую зависимость **медианной** желаемой заработной платы от возраста (**"Возраст"**) и образования (**"Образование"**). На полученной сводной таблице постройте **тепловую карту**. Проанализируйте тепловую карту, сравнив показатели внутри групп.

# %%
# ваш код здесь
mask = (cur_and_data['ЗП (руб)'] < 1000000)
df = cur_and_data.pivot_table(values='ЗП (руб)', index='Образование', columns='Возраст', aggfunc='median', fill_value=0)
# тепловая карта
fig = plt.figure(figsize=(17, 5))
fig = sns.heatmap(
    df,
    cmap='PuBuGn',
    fmt="d",
    linewidths=.5,
    cbar_kws={'label': 'Медиана желаемой ЗП, руб.'}
    )

fig.set_title('Медианная ЗП в зависимости от возраста и уровня образования')
fig.set_xlabel('Возраст соискателя, год')
fig.set_ylabel('Уровень образования')

plt.show()

# %% [markdown]
# Ожидаемо, самые высокие зарплатные ожидания приходятся на категорию с высшим образованием. Наиболее требовательны к зарплате в этой категории люди в промежутке от 33 до 35 лет. Но есть и аномально высокое значение в возрасте 69. Очевидно, есть аномалия в восзрасте 100 лет. Самые низкие ожидания от ЗП у группы со средним и средним специальным образованием. Причем в категории со средним специальным образованием не так сильно ожидаемая ЗП зависит от возраста соискателей.

# %% [markdown]
# 8. Постройте **диаграмму рассеяния**, показывающую зависимость опыта работы (**"Опыт работы (месяц)"**) от возраста (**"Возраст"**). Опыт работы переведите из месяцев в года, чтобы признаки были в едином масштабе. Постройте на графике дополнительно прямую, проходящую через точки (0, 0) и (100, 100). Данная прямая соответствует значениям, когда опыт работы равен возрасту человека. Точки, лежащие на этой прямой и выше нее - аномалии в наших данных (опыт работы больше либо равен возрасту соискателя)

# %%
# диаграмма рассеяния 
fig = plt.figure(figsize=(10, 8))
scatter = sns.scatterplot(
    cur_and_data,
    x='Возраст',
    y=round(cur_and_data['Опыт работы (месяц)'] / 12, 2),
    )

# линия  (0, 0) - (100, 100)
scatter.axline(
    xy1=[0,0], 
    xy2=[100,100], 
    color='r', 
    lw='2'
    )

scatter.set_title('Диаграмма расеяния возраста и опыта работы соискателя')
scatter.set_xlabel('Возраст соискателя, год')
scatter.set_ylabel('Опыт работы, год')
scatter.grid()
plt.show()

# Определяем количество точек выше зеленой прямой
mask = (cur_and_data['Опыт работы (месяц)'] / 12) >= cur_and_data['Возраст']
print(f'Количество точек выше прямой: {cur_and_data[mask].shape[0]} точек')
# Out:
# Количество точек выше прямой: 7 точек

# %% [markdown]
# Мы видим 7 случав, в которых опыт работы привышает или равен возраст соискателя.

# %% [markdown]
# **Дополнительные баллы**
#
# Для получения 2 дополнительных баллов по разведывательному анализу постройте еще два любых содержательных графика или диаграммы, которые помогут проиллюстрировать влияние признаков/взаимосвязь между признаками/распределения признаков. Приведите выводы по ним. Желательно, чтобы в анализе участвовали признаки, которые мы создавали ранее в разделе "Преобразование данных".

# %%
# построим боксплоты, отражающие связь медианной ЗП с городом 
# разделим по полу 
mask1 = (cur_and_data['ЗП (руб)'] < 300000)
data_df = (cur_and_data[mask1])
df = cur_and_data[mask1].groupby(['Пол', 'Возраст',"Город"], as_index=False) ['ЗП (руб)'].median()
plt.figure(figsize=(15,5))
sns.boxplot(data=df, x="Город", y="ЗП (руб)", hue='Пол')
# Out:
# <Axes: xlabel='Город', ylabel='ЗП (руб)'>

# %% [markdown]
# Видим, что самые большие зарплатные ожидания у мужчин-москвичей. У мужчин зарплатные ожидания выше во всех городах.

# %%
# построим скрипичную диаграмму зависимости уровня ЗП от образования 
# с разделением по полу
sns.violinplot(data=data_df, x="Образование", y="ЗП (руб)", hue="Пол",
               split=True, inner="quart", linewidth=1)
sns.despine(left=True)
plt.show()

# %% [markdown]
# Видим, опять же, небольшой перекос в зарплатных ожидаяниях в зависимости от пола. "Скрипка" у группы с высшим образованием более вытянута вверх, т.е. у них меньше ограничений в плане зарплатных ожиданий. В трех другиз группах большая часть зарплатных ожиданий лежит ниже планки 50 т.р. примечательно, что у группы со средним специальным образованием самый сжатых межквартильный диапазон (видимо, относительно узкая сфера примения их навыков диктует большую сжатость зарплатных ожиданий).

# %% [markdown]
# # Очистка данных

# %% [markdown]
# 1. Начнем с дубликатов в наших данных. Найдите **полные дубликаты** в таблице с резюме и удалите их.

# %%
# количество полных дубликатов
print(f'полные дубликаты: {cur_and_data.duplicated().sum()}')
# удалим полные дубликаты
cur_and_data_clean = cur_and_data.drop_duplicates(ignore_index=True)
# Out:
# полные дубликаты: 161

# %% [markdown]
# 2. Займемся пропусками. Выведите информацию **о числе пропусков** в столбцах.

# %%
# ваш код здесь
# нам нужно удалить некоторые технические столбцы
del cur_and_data_clean['per']
del cur_and_data_clean['time']
del cur_and_data_clean['vol']
# чистим данные
df_nan = cur_and_data_clean.isnull().sum()
col = df_nan[df_nan > 0].sort_values(ascending=False)
print('Пропуски в столбцах:')
display(col)
# Out:
# Пропуски в столбцах:
# Опыт работы (месяц)                168
# Последняя/нынешняя должность         2
# Последнее/нынешнее место работы      1
# dtype: int64

# %% [markdown]
# 3. Итак, у нас есть пропуски в 3ех столбцах: **"Опыт работы (месяц)"**, **"Последнее/нынешнее место работы"**, **"Последняя/нынешняя должность"**. Поступим следующим образом: удалите строки, где есть пропуск в столбцах с местом работы и должностью. Пропуски в столбце с опытом работы заполните **медианным** значением.

# %%
# заменяем пустоты на медианные значения
clean_data = cur_and_data_clean.dropna(how='any', subset=['Последняя/нынешняя должность', 'Последнее/нынешнее место работы'])
clean_data = clean_data.fillna(value={'Опыт работы (месяц)':clean_data['Опыт работы (месяц)'].median()})

# количество пропусков
col_nan = clean_data.isnull().sum()
print(f'Количество пропусков в таблице: {col_nan.sum()}')
# Out:
# Количество пропусков в таблице: 0

# %% [markdown]
# 4. Мы добрались до ликвидации выбросов. Сначала очистим данные вручную. Удалите резюме, в которых указана заработная плата либо выше 1 млн. рублей, либо ниже 1 тыс. рублей.

# %%
# фильтрация данных по заданному условию
mask = (clean_data['ЗП (руб)'] > 1e6) | (clean_data['ЗП (руб)'] < 1e3)
# извлекаем индексы
ind = clean_data[mask].index
clean_data_wierd = clean_data.drop(index=ind)
# количество отсеянных
print(ind.value_counts().sum())
# Out:
# 89

# %% [markdown]
# 5. В процессе разведывательного анализа мы обнаружили резюме, в которых **опыт работы в годах превышал возраст соискателя**. Найдите такие резюме и удалите их из данных

# %%
# ваш код здесь
# фильтрация данных 
mask = (clean_data_wierd['Опыт работы (месяц)'] / 12) > clean_data_wierd['Возраст']
# извлечение индексов
ind = clean_data_wierd[mask].index
clean_data_norm = clean_data_wierd.drop(index=ind)

# количество выбросов
print(ind.value_counts().sum())
# Out:
# 7

# %% [markdown]
# 6. В результате анализа мы обнаружили потенциальные выбросы в признаке **"Возраст"**. Это оказались резюме людей чересчур преклонного возраста для поиска работы. Попробуйте построить распределение признака в **логарифмическом масштабе**. Добавьте к графику линии, отображающие **среднее и границы интервала метода трех сигм**. Напомним, сделать это можно с помощью метода axvline. Например, для построение линии среднего будет иметь вид:
#
# `histplot.axvline(log_age.mean(), color='k', lw=2)`
#
# В какую сторону асимметрично логарифмическое распределение? Напишите об этом в комментарии к графику.
# Найдите выбросы с помощью метода z-отклонения и удалите их из данных, используйте логарифмический масштаб. Давайте сделаем послабление на **1 сигму** (возьмите 4 сигмы) в **правую сторону**.
#
# Выведите таблицу с полученными выбросами и оцените, с каким возрастом соискатели попадают под категорию выбросов?

# %%
# гистограмма (с логарифмированием)
hist = sns.histplot(
    data=clean_data_norm, 
    x=np.log(clean_data_norm['Возраст']),
    )
# линия среднего
hist.axvline(np.log(clean_data_norm['Возраст']).mean(), color='r', lw='2')

# строим линию 4 сигм вправо
hist.axvline(np.log(clean_data_norm['Возраст']).mean() + 4 * np.log(clean_data_norm['Возраст']).std(), color='g', lw='2')

hist.set_title('Гистограмма возраста соискателей, Log')
hist.set_xlabel('Возраст соискателя') 
hist.set_ylabel('Количество ')
hist.grid()
plt.show()

# находим выбросы за 4 сигмы
# создаем специальную функцию для этого 
def outliers_z_score_mod(data, feature, log_scale=False, shift=0):
    if log_scale:
        x = np.log(data[feature]+shift)
    else:
        x = data[feature]
    mu = x.mean()
    sigma = x.std()
    bound = mu + 4* sigma
    outliers = data[(x > bound)]
    return(outliers)

# применяем функцию к нашим аномальным данным
outliers = outliers_z_score_mod(clean_data_wierd, 'Возраст', log_scale=True)
display(outliers)
# Out:
#       Ищет работу на должность: Последнее/нынешнее место работы  \
# 33499      Frontend-разработчик                       Freelance
#
#       Последняя/нынешняя должность Обновление резюме        Авто  \
# 33499         Frontend-разработчик        2019-04-19  Не указано
#
#                Образование Пол  Возраст  Опыт работы (месяц)            Город  \
# 33499  среднее специальное   М      100                 30.0  Санкт-Петербург
#
#        ...  сменный график  гибкий график  удаленная работа  вахтовый метод  \
# 33499  ...           False           True              True           False
#
#        полная занятость  частичная занятость  проектная работа  волонтерство  \
# 33499              True                 True              True         False
#
#        стажировка  ЗП (руб)
# 33499        True   60000.0
#
# [1 rows x 23 columns]

# %% [markdown]
# За 4 сигмы у нас вылетел только один человек (неудивительно, т.к. он Frontend-разработчик). Судя по графику, у нас нормальное распредление с правой ассиметрией.
